# %% [markdown]
# # MFCC Language Classifier
#
# This notebook loads the provided train and test splits, extracts MFCC-based features from each audio waveform, trains a language classifier, and shows the evaluation output.

# %%
import os
os.environ.setdefault("MPLCONFIGDIR", "/tmp/mplconfig")

from mfcc_language_classifier import main

results = main()
results["test_accuracy"]
# Out:
# Train shape: (175, 7)
# Test shape: (44, 7)
# language speaker  length
#       SA       A    9501
#       FR       F    6201
#       FR       B   10001
#       SI       C    9001
#       IT       E   15000
# Languages: ['FR', 'IT', 'PO', 'SA', 'SI']
# Train samples: 175
# Test samples: 44
# Feature shape: 120 MFCC-based features per sample
# Training accuracy: 1.000
# Test accuracy: 0.614
#
# Classification report on test set:
#               precision    recall  f1-score   support
#
#           FR       0.54      0.58      0.56        12
#           IT       0.67      1.00      0.80        10
#           PO       1.00      0.40      0.57         5
#           SA       0.56      0.56      0.56         9
#           SI       0.60      0.38      0.46         8
#
#     accuracy                           0.61        44
#    macro avg       0.67      0.58      0.59        44
# weighted avg       0.63      0.61      0.60        44
# Sample predictions:
# ...

# %%
from mfcc_svm_xgboost_experiment import main2

results = main2()
# results["test_accuracy"]
# Out:
# Train shape: (175, 8)
# Test shape: (44, 8)
# Languages: ['FR', 'IT', 'PO', 'SA', 'SI']
# Train language counts:
# language
# FR    48
# IT    40
# SA    37
# SI    30
# PO    20
# Train/validation split: (140, 8) (35, 8)
# Testing SVM MFCC config: MFCCConfig(n_mfcc=13, n_fft=256, hop_length=80, n_mels=26, pre_emphasis=0.97)
# Validation macro F1: 0.6101
# Testing SVM MFCC config: MFCCConfig(n_mfcc=20, n_fft=256, hop_length=160, n_mels=26, pre_emphasis=0.97)
# Validation macro F1: 0.6598
# Testing SVM MFCC config: MFCCConfig(n_mfcc=20, n_fft=512, hop_length=160, n_mels=40, pre_emphasis=0.97)
# Validation macro F1: 0.7648
# Testing SVM MFCC config: MFCCConfig(n_mfcc=26, n_fft=512, hop_length=80, n_mels=40, pre_emphasis=0.97)
# Validation macro F1: 0.7572
# Best SVM config: MFCCConfig(n_mfcc=20, n_fft=512, hop_length=160, n_mels=40, pre_emphasis=0.97) with val macro F1=0.7648
# Testing XGBoost MFCC config: MFCCConfig(n_mfcc=13, n_fft=256, hop_length=80, n_mels=26, pre_emphasis=0.95)
# ...
